# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv("pixel_data_green_.csv")

# %%
df
# Out:
#             Image       Layer    X   Y  Green
# 0     1_saved_bgr   Monolayer   40  28    121
# 1     1_saved_bgr   Monolayer   45  35    120
# 2     1_saved_bgr   Monolayer   41  32    120
# 3     1_saved_bgr   Monolayer   38  29    120
# 4     1_saved_bgr   Monolayer   40  32    120
# ..            ...         ...  ...  ..    ...
# 474  20_saved_bgr  Background  138  47    126
# 475  20_saved_bgr  Background  104  26    126
# 476  20_saved_bgr  Background  133   0    126
# 477  20_saved_bgr  Background  110  43    126
# 478  20_saved_bgr  Background   87  43    127
#
# [479 rows x 5 columns]

# %%
df1=df[df['Layer']=="Monolayer"]

# %%
df1
# Out:
#             Image      Layer    X    Y  Green
# 0     1_saved_bgr  Monolayer   40   28    121
# 1     1_saved_bgr  Monolayer   45   35    120
# 2     1_saved_bgr  Monolayer   41   32    120
# 3     1_saved_bgr  Monolayer   38   29    120
# 4     1_saved_bgr  Monolayer   40   32    120
# ..            ...        ...  ...  ...    ...
# 466  20_saved_bgr  Monolayer  167  230    118
# 467  20_saved_bgr  Monolayer  174  235    118
# 468  20_saved_bgr  Monolayer  286   91    118
# 469  20_saved_bgr  Monolayer  296   73    118
# 470  20_saved_bgr  Monolayer  301   63    120
#
# [151 rows x 5 columns]

# %%
plt.scatter(df1['X'],df1['Green'])

# %%
df_d1=df1[df1["Green"]==117]
df_d1
# Out:
#             Image      Layer    X   Y  Green
# 404  18_saved_bgr  Monolayer  116  53    117
# 407  18_saved_bgr  Monolayer  117  53    117

# %%
df2=df[df['Layer']=="Bilayer"]

# %%
df2
# Out:
#             Image    Layer    X    Y  Green
# 8     1_saved_bgr  Bilayer   16   59    114
# 9     1_saved_bgr  Bilayer   17   57    115
# 10    1_saved_bgr  Bilayer   20   56    115
# 11    1_saved_bgr  Bilayer   23   56    115
# 12    1_saved_bgr  Bilayer   25   61    115
# 13    1_saved_bgr  Bilayer   14   61    115
# 14    1_saved_bgr  Bilayer   18   61    114
# 154   7_saved_bgr  Bilayer  379  204    114
# 155   7_saved_bgr  Bilayer  382  199    114
# 156   7_saved_bgr  Bilayer  378  194    114
# 157   7_saved_bgr  Bilayer  375  207    113
# 158   7_saved_bgr  Bilayer  373  209    114
# 159   7_saved_bgr  Bilayer  370  211    114
# 160   7_saved_bgr  Bilayer  390  206    114
# 161   7_saved_bgr  Bilayer  387  197    114
# 162   7_saved_bgr  Bilayer  384  185    114
# 163   7_saved_bgr  Bilayer  379  178    114
# 164   7_saved_bgr  Bilayer  382  194    114
# 165   7_saved_bgr  Bilayer  373  207    114
# 166   7_saved_bgr  Bilayer  384  205    114
# ...

# %%
plt.scatter(df2['X'],df2['Green'])

# %%
df_d2=df2[(df2["Green"]==118)]
df_d2
# Out:
#             Image    Layer    X    Y  Green
# 435  19_saved_bgr  Bilayer  399  420    118
# 437  19_saved_bgr  Bilayer  400  418    118
# 440  19_saved_bgr  Bilayer  401  420    118

# %%
df3=df[df['Layer']=="Trilayer"]

# %%
df3
# Out:
#             Image     Layer    X    Y  Green
# 15    1_saved_bgr  Trilayer   27   76    118
# 16    1_saved_bgr  Trilayer   27   81    120
# 17    1_saved_bgr  Trilayer   27   77    118
# 18    1_saved_bgr  Trilayer   27   80    120
# 19    1_saved_bgr  Trilayer   27   83    119
# ..            ...       ...  ...  ...    ...
# 446  19_saved_bgr  Trilayer  172  449    115
# 447  19_saved_bgr  Trilayer  331  537    116
# 448  19_saved_bgr  Trilayer  326  535    117
# 449  19_saved_bgr  Trilayer  333  535    117
# 450  19_saved_bgr  Trilayer  337  535    119
#
# [115 rows x 5 columns]

# %%
plt.scatter(df3['X'],df3['Green'])

# %%
df_d3=df3[df3["Green"]>120]
df_d3
# Out:
#             Image     Layer    X    Y  Green
# 386  17_saved_bgr  Trilayer   90  149    122
# 388  17_saved_bgr  Trilayer   76  142    123
# 411  18_saved_bgr  Trilayer  117   19    121
# 413  18_saved_bgr  Trilayer  115    9    140
# 414  18_saved_bgr  Trilayer  113   21    128
# 415  18_saved_bgr  Trilayer  108   28    132
# 442  19_saved_bgr  Trilayer  175  374    126

# %%
df4=df[df['Layer']=="Background"]

# %%
df4
# Out:
#             Image       Layer    X   Y  Green
# 22    1_saved_bgr  Background   17  23    127
# 23    1_saved_bgr  Background   15  18    127
# 24    1_saved_bgr  Background   10  13    127
# 25    1_saved_bgr  Background   19  21    127
# 26    1_saved_bgr  Background   19  28    127
# ..            ...         ...  ...  ..    ...
# 474  20_saved_bgr  Background  138  47    126
# 475  20_saved_bgr  Background  104  26    126
# 476  20_saved_bgr  Background  133   0    126
# 477  20_saved_bgr  Background  110  43    126
# 478  20_saved_bgr  Background   87  43    127
#
# [159 rows x 5 columns]

# %%
plt.scatter(df4["X"],df4["Green"])

# %%
df_d4=df4[df4["Green"]<120]
df_d4
# Out:
#              Image       Layer   X   Y  Green
# 120  5_2_saved_bgr  Background  67  17    118
# 121  5_2_saved_bgr  Background  34  20    118
# 122  5_2_saved_bgr  Background  22  22    118
# 123  5_2_saved_bgr  Background   7  37    117

# %%
df_blue=pd.read_csv("pixel_data_blue_.csv")
df_blue
# Out:
#             Image       Layer    X   Y  Blue
# 0     1_saved_bgr   Monolayer   40  28   125
# 1     1_saved_bgr   Monolayer   45  35   125
# 2     1_saved_bgr   Monolayer   41  32   124
# 3     1_saved_bgr   Monolayer   38  29   123
# 4     1_saved_bgr   Monolayer   40  32   124
# ..            ...         ...  ...  ..   ...
# 474  20_saved_bgr  Background  138  47   129
# 475  20_saved_bgr  Background  104  26   129
# 476  20_saved_bgr  Background  133   0   129
# 477  20_saved_bgr  Background  110  43   129
# 478  20_saved_bgr  Background   87  43   129
#
# [479 rows x 5 columns]

# %%
df_blue1=df_blue[df_blue['Layer']=="Monolayer"]
df_blue1
# Out:
#             Image      Layer    X    Y  Blue
# 0     1_saved_bgr  Monolayer   40   28   125
# 1     1_saved_bgr  Monolayer   45   35   125
# 2     1_saved_bgr  Monolayer   41   32   124
# 3     1_saved_bgr  Monolayer   38   29   123
# 4     1_saved_bgr  Monolayer   40   32   124
# ..            ...        ...  ...  ...   ...
# 466  20_saved_bgr  Monolayer  167  230   120
# 467  20_saved_bgr  Monolayer  174  235   120
# 468  20_saved_bgr  Monolayer  286   91   120
# 469  20_saved_bgr  Monolayer  296   73   120
# 470  20_saved_bgr  Monolayer  301   63   122
#
# [151 rows x 5 columns]

# %%
plt.scatter(df_blue1['X'],df_blue1['Blue'])

# %%
df_blue2=df_blue[df_blue['Layer']=="Bilayer"]
df_blue2
# Out:
#             Image    Layer    X    Y  Blue
# 8     1_saved_bgr  Bilayer   16   59   117
# 9     1_saved_bgr  Bilayer   17   57   118
# 10    1_saved_bgr  Bilayer   20   56   118
# 11    1_saved_bgr  Bilayer   23   56   119
# 12    1_saved_bgr  Bilayer   25   61   119
# 13    1_saved_bgr  Bilayer   14   61   118
# 14    1_saved_bgr  Bilayer   18   61   117
# 154   7_saved_bgr  Bilayer  379  204   116
# 155   7_saved_bgr  Bilayer  382  199   116
# 156   7_saved_bgr  Bilayer  378  194   115
# 157   7_saved_bgr  Bilayer  375  207   115
# 158   7_saved_bgr  Bilayer  373  209   116
# 159   7_saved_bgr  Bilayer  370  211   116
# 160   7_saved_bgr  Bilayer  390  206   116
# 161   7_saved_bgr  Bilayer  387  197   116
# 162   7_saved_bgr  Bilayer  384  185   116
# 163   7_saved_bgr  Bilayer  379  178   115
# 164   7_saved_bgr  Bilayer  382  194   116
# 165   7_saved_bgr  Bilayer  373  207   116
# 166   7_saved_bgr  Bilayer  384  205   116
# 167   7_saved_bgr  Bilayer  332  258   116
# ...

# %%
plt.scatter(df_blue2['X'],df_blue2['Blue'])

# %%
df_blue3=df_blue[df_blue['Layer']=="Trilayer"]
df_blue3
# Out:
#             Image     Layer    X    Y  Blue
# 15    1_saved_bgr  Trilayer   27   76   122
# 16    1_saved_bgr  Trilayer   27   81   124
# 17    1_saved_bgr  Trilayer   27   77   123
# 18    1_saved_bgr  Trilayer   27   80   124
# 19    1_saved_bgr  Trilayer   27   83   124
# ..            ...       ...  ...  ...   ...
# 446  19_saved_bgr  Trilayer  172  449   116
# 447  19_saved_bgr  Trilayer  331  537   117
# 448  19_saved_bgr  Trilayer  326  535   117
# 449  19_saved_bgr  Trilayer  333  535   117
# 450  19_saved_bgr  Trilayer  337  535   119
#
# [115 rows x 5 columns]

# %%
plt.scatter(df_blue3['X'],df_blue3['Blue'])

# %%
df_blue4=df_blue[df_blue['Layer']=="Background"]
df_blue4
# Out:
#             Image       Layer    X   Y  Blue
# 22    1_saved_bgr  Background   17  23   128
# 23    1_saved_bgr  Background   15  18   128
# 24    1_saved_bgr  Background   10  13   127
# 25    1_saved_bgr  Background   19  21   129
# 26    1_saved_bgr  Background   19  28   128
# ..            ...         ...  ...  ..   ...
# 474  20_saved_bgr  Background  138  47   129
# 475  20_saved_bgr  Background  104  26   129
# 476  20_saved_bgr  Background  133   0   129
# 477  20_saved_bgr  Background  110  43   129
# 478  20_saved_bgr  Background   87  43   129
#
# [159 rows x 5 columns]

# %%
plt.scatter(df_blue4['X'],df_blue4['Blue'])
